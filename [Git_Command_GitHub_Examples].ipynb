# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/CodeData/GitHub_Examples
# Out:
# /content/drive/MyDrive/CodeData/GitHub_Examples

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# !git add .
# !git commit -m 'commit'
# !git push
# Out:
# [main 9e3f9e1] commit
#  21 files changed, 12440 insertions(+), 220 deletions(-)
#  create mode 100644 AWS_Sagemaker_CustomScript.ipynb
#  create mode 100644 AWS_Sagemaker_CustomScript_Data_abalone.test
#  create mode 100644 AWS_Sagemaker_CustomScript_Data_abalone.train_0
#  create mode 100644 AWS_Sagemaker_CustomScript_Data_abalone.train_1
#  create mode 100644 AWS_Sagemaker_CustomScript_Data_abalone.validation
#  rename BXAI_ESN_Minimal_MackeyGlass_t17.txt => BXAI_Data_MackeyGlass_t17.txt (100%)
#  rename BXAI_Pytocrh_ESN_AE.py => BXAI_ESN_AE_Pytocrh.py (100%)
#  delete mode 100644 BXAI_ESN_MakeyGlass_Result.ipynb
#  create mode 100644 BXAI_ESN_pytorch.py
#  create mode 100644 BXAI_ESN_pytorch_Ex_MackeyGlass.ipynb
#  create mode 100644 BXAI_ESN_pytorch_Ex_MackeyGlass_2readouts.ipynb
#  delete mode 100644 BXAI_Pytorch_ESN.py
#  create mode 100644 FNC_TA_RSI_GA.ipynb
#  create mode 100644 QC_Practice.ipynb
#  create mode 100644 QC_Qiskit_Basic.ipynb
#  create mode 100644 QC_Qiskit_Basic_after_Lecture.ipynb
#  rewrite TensorFlow_DNN.ipynb (92%)
#  rewrite TensorFlow_GenerativeModel.ipynb (96%)
#  create mode 100644 XAI_CAM_GradCAM.ipynb
#  rewrite [Git_Command_GitHub_Examples].ipynb (86%)
# Enumerating objects: 24, done.
# Counting objects: 100% (24/24), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (19/19), done.
# Writing objects: 100% (19/19), 4.99 MiB | 9.42 MiB/s, done.
# Total 19 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To https://github.com/w0v5eu8/Examples.git
#    ea026c6..9e3f9e1  main -> main

# %%
# !git pull
# Out:
# Already up to date.
