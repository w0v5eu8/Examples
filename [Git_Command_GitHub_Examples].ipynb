# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/CodeData/Code/GitHub_Examples
# Out:
# /content/drive/MyDrive/CodeData/Code/GitHub_Examples

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# !git add .
# !git commit -m 'commit'
# !git push
# Out:
# [master 022fcff] commit
#  12 files changed, 795 insertions(+), 4 deletions(-)
#  create mode 100644 BXAI_ESN1.py
#  create mode 100644 BXAI_ESN1_MakeyGlass_Result.ipynb
#  create mode 100644 BXAI_Pytocrh_ESN.py
#  create mode 100644 BXAI_Pytocrh_ESN_AE.py
#  create mode 100644 ESN_Minimal.ipynb
#  create mode 100644 Lecture_DL1_GenerativeModel.ipynb
#  rewrite Lecture_DL1_RNN_LSTM.ipynb (94%)
#  create mode 100644 Lecture_IAI_Clustering.ipynb
#  create mode 100644 Lecture_IAI_PCA.ipynb
#  rewrite Lecture_IAI_SVM_DT_XGBOOST.ipynb (71%)
#  rewrite [GIT_Command_GitHub_Examples].ipynb (74%)
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (14/14), 3.92 MiB | 5.66 MiB/s, done.
# Total 14 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/w0v5eu8/GitHub_Examples.git
#    14768fb..022fcff  master -> master

# %%
# !git pull
# Out:
# Already up to date.
